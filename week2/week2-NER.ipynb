# %% [markdown]
# # Recognize named entities on Twitter with LSTMs
#
# In this assignment, you will use a recurrent neural network to solve Named Entity Recognition (NER) problem. NER is a common task in natural language processing systems. It serves for extraction such entities from the text as persons, organizations, locations, etc. In this task you will experiment to recognize named entities from Twitter.
#
# For example, we want to extract persons' and organizations' names from the text. Than for the input text:
#
#     Ian Goodfellow works for Google Brain
#
# a NER model needs to provide the following sequence of tags:
#
#     B-PER I-PER    O     O   B-ORG  I-ORG
#
# Where *B-* and *I-* prefixes stand for the beginning and inside of the entity, while *O* stands for out of tag or no tag. Markup with the prefix scheme is called *BIO markup*. This markup is introduced for distinguishing of consequent entities with similar types.
#
# A solution of the task will be based on neural networks, particularly, on Bi-Directional Long Short-Term Memory Networks (Bi-LSTMs).
#
# ### Libraries
#
# For this task you will need the following libraries:
#  - [Tensorflow](https://www.tensorflow.org) — an open-source software library for Machine Intelligence.
#
# In this assignment, we use Tensorflow 1.15.0. You can install it with pip:
#
#     !pip install tensorflow==1.15.0
#
#  - [Numpy](http://www.numpy.org) — a package for scientific computing.
#
# If you have never worked with Tensorflow, you would probably need to read some tutorials during your work on this assignment, e.g. [this one](https://www.tensorflow.org/tutorials/recurrent) could be a good starting point.

# %% [markdown]
# ### Data
#
# The following cell will download all data required for this assignment into the folder `week2/data`.

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

if IN_COLAB:
    ! wget https://raw.githubusercontent.com/hse-aml/natural-language-processing/master/setup_google_colab.py -O setup_google_colab.py
    import setup_google_colab
    setup_google_colab.setup_week2()

import sys
sys.path.append("..")
from common.download_utils import download_week2_resources

download_week2_resources()
# Out:
# File data/train.txt is already downloaded.
# File data/validation.txt is already downloaded.
# File data/test.txt is already downloaded.

# %% [markdown]
# ### Load the Twitter Named Entity Recognition corpus
#
# We will work with a corpus, which contains tweets with NE tags. Every line of a file contains a pair of a token (word/punctuation symbol) and a tag, separated by a whitespace. Different tweets are separated by an empty line.
#
# The function *read_data* reads a corpus from the *file_path* and returns two lists: one with tokens and one with the corresponding tags. You need to complete this function by adding a code, which will replace a user's nickname to `<USR>` token and any URL to `<URL>` token. You could think that a URL and a nickname are just strings which start with *http://* or *https://* in case of URLs and a *@* symbol for nicknames.

# %%
import re
URL_REGEX = "(https?|ftp|file):\/\/[\-A-Za-z0-9+&@#\/%?=~_|!:,.;]*[\-A-Za-z0-9+&@#\/%=~_|]"
USER_REGEX = '@([A-Za-z0-9_]+)'

# %%
def replace_urls(token):
    return re. sub(URL_REGEX, '<URL>', token)

def replace_username(token):
    return re.sub(USER_REGEX, '<USR>', token)

# %%
assert replace_urls('http://t.co/eQmogqqABK this is a tweet with url') == '<URL> this is a tweet with url'

# %%
assert replace_username('this is a tweet from a user @espoir_mur') == 'this is a tweet from a user <USR>'

# %%
def read_data(file_path):
    tokens = []
    tags = []
    
    tweet_tokens = []
    tweet_tags = []
    for line in open(file_path, encoding='utf-8'):
        line = line.strip()
        if not line:
            if tweet_tokens:
                tokens.append(tweet_tokens)
                tags.append(tweet_tags)
            tweet_tokens = []
            tweet_tags = []
        else:
            token, tag = line.split()
            token = replace_urls(token)
            token = replace_username(token)
            tweet_tokens.append(token)
            tweet_tags.append(tag)
    return tokens, tags

# %% [markdown]
# And now we can load three separate parts of the dataset:
#  - *train* data for training the model;
#  - *validation* data for evaluation and hyperparameters tuning;
#  - *test* data for final evaluation of the model.

# %%
train_tokens, train_tags = read_data('data/train.txt')
validation_tokens, validation_tags = read_data('data/validation.txt')
test_tokens, test_tags = read_data('data/test.txt')

# %% [markdown]
# You should always understand what kind of data you deal with. For this purpose, you can print the data running the following cell:

# %%
for i in range(3):
    for token, tag in zip(train_tokens[i], train_tags[i]):
        print('%s\t%s' % (token, tag))
    print()
# Out:
# RT	O
# <USR>	O
# :	O
# Online	O
# ticket	O
# sales	O
# for	O
# Ghostland	B-musicartist
# Observatory	I-musicartist
# extended	O
# until	O
# 6	O
# PM	O
# EST	O
# due	O
# to	O
# high	O
# demand	O
# .	O
# Get	O
# them	O
# before	O
# they	O
# sell	O
# out	O
# ...	O
#
# Apple	B-product
# MacBook	I-product
# Pro	I-product
# A1278	I-product
# 13.3	I-product
# "	I-product
# Laptop	I-product
# -	I-product
# MD101LL/A	I-product
# (	O
# June	O
# ,	O
# 2012	O
# )	O
# -	O
# Full	O
# read	O
# by	O
# eBay	B-company
# <URL>	O
# <URL>	O
#
# Happy	O
# Birthday	O
# <USR>	O
# !	O
# May	O
# Allah	B-person
# s.w.t	O
# bless	O
# you	O
# with	O
# goodness	O
# and	O
# happiness	O
# .	O

# %% [markdown]
# ### Prepare dictionaries
#
# To train a neural network, we will use two mappings:
# - {token}$\to${token id}: address the row in embeddings matrix for the current token;
# - {tag}$\to${tag id}: one-hot ground truth probability distribution vectors for computing the loss at the output of the network.
#
# Now you need to implement the function *build_dict* which will return {token or tag}$\to${index} and vice versa.

# %%
from collections import defaultdict

# %%
def build_dict(tokens_or_tags, special_tokens):
    """
        tokens_or_tags: a list of lists of tokens or tags
        special_tokens: some special tokens
    """
    # Create a dictionary with default value 0
    token_to_index = defaultdict(lambda: 0)
    index_to_token = list()
    index_to_token_set = set()
    
    
    # Create mappings from tokens (or tags) to indices and vice versa.
    # At first, add special tokens (or tags) to the dictionaries.
    # The first special token must have index 0.
    
    # Mapping tok2idx should contain each token or tag only once. 
    # To do so, you should:
    # 1. extract unique tokens/tags from the tokens_or_tags variable, which is not
    #    occur in special_tokens (because they could have non-empty intersection)
    # 2. index them (for example, you can add them into the list idx2tok
    # 3. for each token/tag save the index into tok2idx).
    
    for index, special_token in enumerate(special_tokens):
        index_to_token_set.add(special_token)
        index_to_token.append(special_token)
        
    for sentence_index, token_or_tag in enumerate(tokens_or_tags):
        for word_index, word_or_tag in enumerate(token_or_tag, start=len(special_tokens)):
            if word_or_tag not in index_to_token_set:
                index_to_token_set.add(word_or_tag)
                index_to_token.append(word_or_tag)
    token_to_index  = {token : index for index, token in enumerate(index_to_token)}
    return token_to_index, index_to_token

# %%
actual_token_to_index, actual_index_to_token = build_dict([['espoir', 'is', 'working ', 'on', 'an', 'nlp', 'exercice']] , ['<UNK>', '<PAD>'])

expected_token_to_index, expected_index_to_token  = {'<UNK>': 0, 
                                                     '<PAD>': 1, 
                                                     'espoir': 2, 
                                                     'is': 3, 
                                                     'working ': 4, 
                                                     'on': 5, 
                                                     'an': 6, 
                                                     'nlp': 7, 
                                                     'exercice': 8},['<UNK>', '<PAD>', 'espoir', 'is', 'working ', 'on', 'an', 'nlp', 'exercice']
assert actual_index_to_token == expected_index_to_token
assert actual_token_to_index == expected_token_to_index

# %% [markdown]
# After implementing the function *build_dict* you can make dictionaries for tokens and tags. Special tokens in our case will be:
#  - `<UNK>` token for out of vocabulary tokens;
#  - `<PAD>` token for padding sentence to the same length when we create batches of sentences.

# %%
special_tokens = ['<UNK>', '<PAD>']
special_tags = ['O']

# Create dictionaries 
token_to_index, index_to_token = build_dict(train_tokens + validation_tokens, special_tokens)
tag_to_index, index_to_tag = build_dict(train_tags, special_tags)

# %%
assert token_to_index['<UNK>'] == 0 
assert index_to_token[0] == '<UNK>'
assert list(tag_to_index.keys()) == list(index_to_tag)
for index in tag_to_index.values():
    assert index in range(0, len(index_to_tag))

# %%
def words_to_indexes(tokens_list):
    return [token_to_index.get(word) for word in tokens_list]

def tags_to_indexes(tags_list):
    return [tag_to_index.get(tag) for tag in tags_list]

def indexes_to_tokens(indexes):
    return [index_to_token[index] for index in indexes]

def indexes_to_tags(indexes):
    return [index_to_tag[index] for index in indexes]

# %% [markdown]
# ### Generate batches
#
# Neural Networks are usually trained with batches. It means that weight updates of the network are based on several sequences at every single time. The tricky part is that all sequences within a batch need to have the same length. So we will pad them with a special `<PAD>` token. It is also a good practice to provide RNN with sequence lengths, so it can skip computations for padding parts. We provide the batching function *batches_generator* readily available for you to save time.

# %%
import numpy as np

# %%
def batches_generator(batch_size, tokens, tags,
                      shuffle=True, allow_smaller_last_batch=True):
    """Generates padded batches of tokens and tags."""
    
    n_samples = len(tokens)
    if shuffle:
        order = np.random.permutation(n_samples)
    else:
        order = np.arange(n_samples)

    n_batches = n_samples // batch_size
    if allow_smaller_last_batch and n_samples % batch_size:
        n_batches += 1

    for k in range(n_batches):
        batch_start = k * batch_size
        batch_end = min((k + 1) * batch_size, n_samples)
        current_batch_size = batch_end - batch_start
        x_list = []
        y_list = []
        max_len_token = 0
        for index in order[batch_start: batch_end]:
            #print(f'the token I am getting are {tokens[index]}')
            x_list.append(words_to_indexes(tokens[index]))
            y_list.append(tags_to_indexes(tags[index]))
            #print(f'the tags am getting are {tags[index]}')
            max_len_token = max(max_len_token, len(tags[index]))
            
        # Fill in the data into numpy nd-arrays filled with padding indices.
        x = np.ones([current_batch_size, max_len_token], dtype=np.int32) * token_to_index['<PAD>']
        y = np.ones([current_batch_size, max_len_token], dtype=np.int32) * tag_to_index['O']
        lengths = np.zeros(current_batch_size, dtype=np.int32)
        for n in range(current_batch_size):
            utt_len = len(x_list[n])
            x[n, :utt_len] = x_list[n]
            lengths[n] = utt_len
            y[n, :utt_len] = y_list[n]
        #print(f'for the following tokens  {tokens[index]}, the tags am getting are {tags[index]}, and their indexes are, {tags_to_indexes(tags[index])}')
        yield x, y, lengths

# %% [markdown]
# some checking;..

# %%
for x_batch, y_batch, lengths in batches_generator(1,  train_tokens , train_tags,): 
    for tokens, tags in zip(x_batch, y_batch):
        print(f"The sentence is : {' '.join(indexes_to_tokens(tokens))}") 
        print("***" * 5)
        print(f"The tags are {' '.join(indexes_to_tags(tags))}")
    print("===" * 4)
# Out:
# The sentence is : So happy moving into my new place on Tuesday !
# ***************
# The tags are O O O O O O O O O O
# ============
# The sentence is : 63,000 people affected by UCF #data #breach : [ welive# security.com ] The University of Central Florida ( UCF ) has… <URL>
# ***************
# The tags are O O O O B-other O O O O O O O B-other I-other I-other I-other I-other O B-other O O O
# ============
# The sentence is : Middlesex Hospital suffers patient data security breach - <URL> ( blog ) <URL> #datasecurity
# ***************
# The tags are B-other I-other O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : When the sun smiles , the birds smile back ! <URL>
# ***************
# The tags are O O O O O O O O O O O O O O
# ============
# The sentence is : you are not bringing tthe $ 10.000 a week for life on the 30th
# ***************
# The tags are O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Our goal is 1,000 supporters ( of any pledge level ) by next Tuesday . Can you help ? <URL> #noenemies
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> <USR> I'm not kidding ! I used a book which was published in 2008 ( last year) ... it was an awesome book !
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Twenty five after Seven
# ***************
# The tags are O O O O
# ============
# The sentence is : keep on tweeting ! may mas bibilis pa dyan eh . konting usad lang ! kaya naten to . push pa ! #PSYLabanNiYna l #PushAwardsKathNiels twentyfve
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Friday <URL>
# ***************
# The tags are O O O O O
# ============
# The sentence is : <USR> SHIT . I'm playing this tomorrow when I get home ( HOHO) . I bet the servers will be on fire though .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Bio Spot 6 Month Spot On Flea &amp; Tick Cats 5 lbs &amp; Over #E_BAY #forsale #supplies #pet #SFO <URL>
# ***************
# The tags are B-product I-product O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Pope insists he left his cigarettes at Holyroodhouse . One 's asked the staff to have a look around . The DoE may well have p ...
# ***************
# The tags are O O O B-person O O O O O O B-facility O O O O O O O O O O O O O B-other O O O O O
# ============
# The sentence is : <USR> to be fair though it 's roughly the millionth time he 's played Tony Blair .
# ***************
# The tags are O O O O O O O O O O O O O O B-person I-person O
# ============
# The sentence is : This is a " false-flag " assertion about the San Bernardino shooting today . Worth a look . <URL> …
# ***************
# The tags are O O O O O O O O O B-geo-loc I-geo-loc O O O O O O O O O
# ============
# The sentence is : belles mansion 4 bday dinner . eventhough its a day early . *N*I*K*K*I*
# ***************
# The tags are B-facility I-facility O O O O O O O O O O O
# ============
# The sentence is : Sharing every feeling may not be the smartest thing to do toda ... More for Virgo <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O B-other O
# ============
# The sentence is : <USR> Now , why couldn't this show be tomorrow ? I didn't arrive in time to go !! I know y'all are having fun !
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Twitter : Happy 4th of July posts
# ***************
# The tags are O O O O O O B-other I-other I-other O
# ============
# The sentence is : RT <USR> : Have A Bless Monday MiKenJo :) <USR> <USR> <USR> <USR> #MiKenJoWalangBibitiw
# ***************
# The tags are O O O O O O O B-other O O O O O O
# ============
# The sentence is : Your growing excitement over an innovative idea may cause you ... More for Virgo <URL>
# ***************
# The tags are O O O O O O O O O O O O O B-other O
# ============
# The sentence is : RT <USR> : I feel incomplete without the new album being released , I , we , need you to hear it asap , the 23rd can't come quick enough ...
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : February 04 , 2015 at 01:16 AM
# ***************
# The tags are O O O O O O O
# ============
# The sentence is : I need a syringe of anything you want but which will switch me off till tomorrow noon , anyone ??
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> lol . Try cudos ! I neva been round this time doe .
# ***************
# The tags are O O O O O O O O O O O O O O
# ============
# The sentence is : Wendy 's investigating a possible credit card breach <URL>
# ***************
# The tags are B-company I-company O O O O O O O
# ============
# The sentence is : Check out our #newcomicday highlights here : <URL>
# ***************
# The tags are O O O O O O O O
# ============
# The sentence is : CLUB BLU tonite ...... 90 's music .. oldskool night wiith dj finese
# ***************
# The tags are B-facility I-facility O O O O O O O O O B-musicartist I-musicartist
# ============
# The sentence is : Current Conditions : 42.0 F , Clear - 6:33 AM EDT May . 4 <URL> #wvwx #wx #wv
# ***************
# The tags are O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : People at post advised to shelter in place : Fort Hood confirms that a shooting has occurred at the U.S. Army p ... <URL>
# ***************
# The tags are O O O O O O O O O B-facility I-facility O O O O O O O O B-other I-other O O O
# ============
# The sentence is : Edmonton dealers raise $320000 for Special Olympics : By Tim Yip , Edmonton Journal September 17 , 2010 2:03 PM Chari ... <URL>
# ***************
# The tags are B-geo-loc O O O O B-other I-other O O B-person I-person O B-other I-other O O O O O O O O O
# ============
# The sentence is : 7 people injured in Indianapolis shooting : Seven people were shot and injured on early Saturday morning in an ... <URL>
# ***************
# The tags are O O O O B-geo-loc O O O O O O O O O O O O O O O O
# ============
# The sentence is : " <USR> : Mon bulletin ... Il joue a quoi mon prof d'espagnol ??? Grosse poukave <URL> " PTDR moi c tout lcontraire sport g 0
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Dee Whit having something Saturday , ima slide through &amp; show my face .
# ***************
# The tags are O O O B-person I-person O O O O O O O O O O O O
# ============
# The sentence is : next Friday , the 24th both my bands are playing at Swayzes Venue . Please come support !!!
# ***************
# The tags are O O O O O O O O O O O B-facility I-facility O O O O O
# ============
# The sentence is : RT <USR> : Live your life while you still can . Tomorrow is promised to nobody .
# ***************
# The tags are O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Kristen is MY LIFE . She made me who i am today , I was a fucker before her , she fixed me . And so did Robert .
# ***************
# The tags are B-person O O O O O O O O O O O O O O O O O O O O O O O O O O B-person O
# ============
# The sentence is : RT <USR> : It 's Saturday . That Saturday . A Saturday with MOTD at the end of it . Oi Oi !
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : No I 'm not saying I 'm sorry One day , maybe 'll meet again No No No No ( 8 )
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : will go at my B-day party . Fucking can't believe it !
# ***************
# The tags are O O O O O O O O O O O O
# ============
# The sentence is : Listen to Goodbye Tomorrow - NoOne or NoThing feat . Lil Herb on <USR> <URL>
# ***************
# The tags are O O B-product I-product I-product I-product I-product I-product O O B-musicartist I-musicartist O O O
# ============
# The sentence is : Feelings toward casually graduating college tomorrow : <URL>
# ***************
# The tags are O O O O O O O O
# ============
# The sentence is : <USR> yesterday i had a kings of leon marathon . i slept happy ll !
# ***************
# The tags are O O O O O B-musicartist I-musicartist I-musicartist O O O O O O O
# ============
# The sentence is : Been real busy the last few weeks . Had a great time all round now back to work tomorrow after a long half term .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Stop by teh Nex-Tech and Nex-Tech Wireless tent at TailGreat tomorrow evening for Free ice cream , bottles of water and an FHSU foam finger .
# ***************
# The tags are O O O B-company O B-company I-company O O B-other O O O O O O O O O O O O B-sportsteam O O O
# ============
# The sentence is : #BREAKING : People injured in shooting at Santa Monica college . President Obama at fundraiser a few blocks away <URL>
# ***************
# The tags are O O O O O O O B-geo-loc I-geo-loc O O B-person I-person O O O O O O O
# ============
# The sentence is : [#LosAngelesWeather] , #Los Angeles weather July 7 , 8 , 9 , 10 , 11 , 12 2015 <URL>
# ***************
# The tags are O O B-geo-loc I-geo-loc O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Jun Takahashi <URL>
# ***************
# The tags are O O O B-person I-person O
# ============
# The sentence is : BoiRevolution : After Dark ! Mondays @ 11pm/EST . Only on www.blogtalkradio.com/boi-revolution ( RETWEET PLEASE )
# ***************
# The tags are O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> MA WATCH KOOO AHAY SI BEA MAY VIDEOS MAN DU MAHIBI KO KAGINA SANG GIN BASHAHAN SI HARRY DU PANDESAL ABS YA
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : if after watcing this you dont accomplish your dream by tomorrow idk yo <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O O O
# ============
# The sentence is : found some really funny pictures of 1st year : L going to put them on facebook now !!
# ***************
# The tags are O O O O O O O O O O O O O O O B-company O O
# ============
# The sentence is : Fucking passion pit is coming to Boston in July and it 's already sold out k
# ***************
# The tags are O B-musicartist I-musicartist O O O B-geo-loc O O O O O O O O O
# ============
# The sentence is : Amazon U.K. Offering HTC Desire Z Unlocked October 11 : We just got official word of the HTC Desire Z earlier in Lo ... <URL>
# ***************
# The tags are O O O B-product I-product I-product O O O O O O O O O O O B-product I-product I-product O O O O O
# ============
# The sentence is : <USR> Mechanical keyboards are so prohibitively expensive in my 3rd world shithole .. At least the keyboard of my Thinkpad ain't bad
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O B-product O O
# ============
# The sentence is : You may be unnecessarily self-critical now because you want to ... More for Libra <URL>
# ***************
# The tags are O O O O O O O O O O O O O B-other O
# ============
# The sentence is : 10 short articles for $5 #fiverr #content #100words #writing <URL> April 30 , 2015 at 06:01 PM
# ***************
# The tags are O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> It has been 3 years and never an answer . It just drove me nuts , but i'm not mad . Just thinkin not again ya know .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <URL> January 07 , 2015 at 03:26 PM
# ***************
# The tags are O O O O O O O O
# ============
# The sentence is : <USR> cause I was too busy singing my heart out and all . It 's hard to go crazy when you're trying to record something :p
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : About to get ready for work...don't have a good feeling about tonight #famouslastwords
# ***************
# The tags are O O O O O O O O O O O O O
# ============
# The sentence is : " <USR> : LOL . Going thru this again . They just don't die easy . Abortion Monday <URL> " RT
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : To Kill A Mockingbird and Roll of Thunder Hear My Cry were my 2 favorite books in middle school/9th grade
# ***************
# The tags are B-product I-product I-product I-product O B-product I-product I-product I-product I-product I-product O O O O O O O O O
# ============
# The sentence is : <USR> as a personal experience , I can tell that it takes a day before you can form hypotheses . Many don't even get that far
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Wats good for tonight any partys
# ***************
# The tags are O O O O O O
# ============
# The sentence is : FTM Wed Bike Night W/Joe Rock &amp; Allstars #constantcontact <URL>
# ***************
# The tags are B-company B-other I-other I-other B-musicartist I-musicartist I-musicartist I-musicartist O O
# ============
# The sentence is : WHATS GOODIE EVERY1 COOLIN COOLIN FEELIN THE BREEZE #FRIDAY#MANIA
# ***************
# The tags are O O O O O O O O O
# ============
# The sentence is : total 9 for Clark Duke RT <USR> : Just watched hot tub time machine . Funny film ! Quite enjoyable ! Hmm 7.5 /10
# ***************
# The tags are O O O B-person I-person O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : BASE : #BlueHens open CAA schedule Friday vs . Hofstra <URL> #BHStateOfMind
# ***************
# The tags are O O O O O B-sportsteam O B-other O O O O B-sportsteam O O
# ============
# The sentence is : Xbox 360 : Enslaved : Odyssey to the West Demo Coming to PlayStation Network on September ... <URL>
# ***************
# The tags are B-product I-product O B-product I-product I-product I-product I-product I-product O O O B-product I-product O O O O
# ============
# The sentence is : RT <USR> : <USR> <USR> wow may meet up #ALDUBKapitLang
# ***************
# The tags are O O O O O O O O O O
# ============
# The sentence is : i s2g if i'm stalking in july and anyone gets in my way you're dead bc i'm sneaking out for that shit
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Forgot to buy your ticket , still want to come out ! It 's ok , you can buy a ticket right at the BBQ tomorrow ! A ... <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : That 's crazy .. Pray for the people in the Saylorsburg shooting
# ***************
# The tags are O O O O O O O O O O B-geo-loc O
# ============
# The sentence is : RT <USR> : [ PIC ] 150325 The 9th Asian Film Awards - HOYA ( Cr . VAVAVOOM0328 ) <URL> <URL>
# ***************
# The tags are O O O O O O O B-other I-other I-other I-other I-other O B-other I-other I-other I-other I-other I-other O O
# ============
# The sentence is : <USR> <USR> <USR> <USR> <USR> You ladies were great today . Have a wicked weekend . xx
# ***************
# The tags are O O O O O O O O O O O O O O O O O
# ============
# The sentence is : June 11 | Daily Devotion <URL>
# ***************
# The tags are O O O O O O
# ============
# The sentence is : tos <URL> August 02 , 2015 at 12:22 PM
# ***************
# The tags are O O O O O O O O O
# ============
# The sentence is : RT <USR> : Bas Dost from Wolfsburg to Newcastle should be a done deal by tomorrow . #nufc
# ***************
# The tags are O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : tomorow on day off !! youppppiiieeee
# ***************
# The tags are O O O O O O
# ============
# The sentence is : Bringing this one back . From last March . On tackles . On intent . More to say but for lack of time , here 's this : <URL> ( Colin )
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O B-person O
# ============
# The sentence is : <USR> <USR> wag mo na I mention yan . Bakla yan . Onga ako magbabayad ng pamasahe mo . Para may barkada ako dito
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : may number combination ka na , kaso hindi mo tinaya sa lotto , tas biglang lumabas yung number mo , #AyanSayangTuloy <USR>
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> haha yes :) have to go speak tomorrow :) good night xxx
# ***************
# The tags are O O O O O O O O O O O O O
# ============
# The sentence is : <USR> How do you think your parents are able to help you with your homework ? It 's because they learned the same thing years ago .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Deadly Shooting Reported on Northern Arizona University 's Flagstaff Campus <URL> …
# ***************
# The tags are O O O O B-facility I-facility I-facility O B-geo-loc O O O
# ============
# The sentence is : comme celle a ma soeur ou celle comme mon beau frere
# ***************
# The tags are O O O O O O O O O O O
# ============
# The sentence is : OMG ! Miley Cyrus Has A 14-Year-Old Stalker !: First Paris Hilton , now Miley Cyrus ! Cops responded to a break in cal ... <URL>
# ***************
# The tags are O O B-person I-person O O O O O O B-person I-person O O B-person I-person O O O O O O O O O O
# ============
# The sentence is : A world In which Mark May and Lou Holtz are allowed to call a bowl game is a world I do not want to live in .
# ***************
# The tags are O O O O B-person I-person O B-person I-person O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : I'm so ready for July . Family trip to Michigan and it better be nice out .
# ***************
# The tags are O O O O O O O O O B-geo-loc O O O O O O O
# ============
# The sentence is : <USR> I honestly don't know how she does it , she works from 8am till 9pm at least 4 days a week . She 's off mon/tues ,
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Pre Order Jaket Korea BARCA " RIDE " sd 7 Jan , 185K belum ongkir <USR> SMS/WA 081235994171 pin 512A3491 <URL>
# ***************
# The tags are O O B-product I-product I-product I-product I-product I-product I-product O O O O O O O O O O O O
# ============
# The sentence is : <USR> GOOD LUCK MEETING JAKE TOMORROW IM SO EXCITED FOR YOU OMG !!!!
# ***************
# The tags are O O O O B-person O O O O O O O O
# ============
# The sentence is : A #FourthTeenager was arrested over #TalkTalk data breach view more at <URL>
# ***************
# The tags are O O O O O B-company O O O O O O
# ============
# The sentence is : Well .. I do my 5th fact hehe natbynature <USR> <URL>
# ***************
# The tags are O O O O O O O O O O O
# ============
# The sentence is : to all my girls in london or travelling up tomorrow i love and miss you wish i could be there ! NEXT YEAR I WILL !
# ***************
# The tags are O O O O O B-geo-loc O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> tape him . that would be great for YEARS later !!!
# ***************
# The tags are O O O O O O O O O O O O
# ============
# The sentence is : Anyway , come confess your crimes on Thursday 's second annual #DomesticExtremist Awareness Day
# ***************
# The tags are O O O O O O O O O O O O O O
# ============
# The sentence is : 3 dead in courthouse shooting in Delaware : WILMINGTON , Del . ( AP ) — A gunman opened fire Monday morning in a Dela ... <URL>
# ***************
# The tags are O O O O O O B-geo-loc O B-geo-loc O B-geo-loc O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : TOMORROWS MONDAY AND I DONT HAVE TO WORRY ABOUT A THING CAUSE ITS SUMMER
# ***************
# The tags are O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Oh haaaaiiiii sunny Saturday !
# ***************
# The tags are O O O O O O O O
# ============
# The sentence is : Oakland Family Services #HIPAA breach ; 16K clients affected by phishing : <URL> … Org . notification : <URL> …
# ***************
# The tags are B-other I-other I-other B-other O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Join the TIFO CREW says <USR> 's Dan Martin in this week 's S8 blog : <URL>
# ***************
# The tags are O O O O O B-other I-other O O O B-person I-person O O O O B-other I-other O O
# ============
# The sentence is : <USR> oh ? What did you do for my half birthday , *tomorrow* !
# ***************
# The tags are O O O O O O O O O O O O O O
# ============
# The sentence is : Can have any girl I choose but as time goes by baby im goin home wit u
# ***************
# The tags are O O O O O O O O O O O O O O O O O
# ============
# The sentence is : #BREAKING <USR> says that the shooting was part of long custody dispute . No more questions permitted . 2 officers shot ok #Wilmington
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O B-geo-loc
# ============
# The sentence is : It 's official . Next book club selection is " Not a Genuine Black Man " by <USR> I saw the show a few years ago and it was fantastic .
# ***************
# The tags are O O O O O O O O O O B-other I-other I-other I-other I-other O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : ( 25 ) More photos of Justin Bieber at the 2015 EMA 's in Milan , Italy . ( October 25 ) <URL>
# ***************
# The tags are O O O O O O O O O B-musicartist I-musicartist O O O B-other O O B-geo-loc O B-geo-loc O O O O O O
# ============
# The sentence is : <USR> PTTTTDDDDDDDDR c'est pas mon gars wsh
# ***************
# The tags are O O O O O O O
# ============
# The sentence is : RT <USR> : Aqa eng lit pls be a blessing tomorrow #litb3
# ***************
# The tags are O O O O O O O O O O O O
# ============
# The sentence is : White House Talking Points On #Chattanooga #ChattanoogaShooting pic.twitter.com/zNxJiOwKdS
# ***************
# The tags are B-other I-other O O O B-geo-loc O O
# ============
# The sentence is : Going to start #HelloMornings on Oct 1 - Check it out on <USR>
# ***************
# The tags are O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : <USR> HOW ARE YOU GONNA DO THIS ON THE LAST SUNDAY NIGHT GAME OF THE SEASON
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : ' Breaking Dawn ' Returns to Vancouver on January 11th <URL>
# ***************
# The tags are O B-movie I-movie O O O B-geo-loc O O O O
# ============
# The sentence is : It is Friday afternoon adn I could n't be happier . Ending a crappy week on a good note is always nice .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Surely mags will line up to feature . RT <USR> : Lindsay Lohan fails court-mandated drug test , faces more jail time <URL>
# ***************
# The tags are O O O O O O O O O O O B-person I-person O O O O O O O O O O
# ============
# The sentence is : If you are in Belfast this weekend go to Botanic Gdns , for Taste N I , free food drink face painting etc . Should be good day out . Sat &amp; Sun
# ***************
# The tags are O O O O B-geo-loc O O O O B-facility I-facility O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : every time u smile =)
# ***************
# The tags are O O O O O
# ============
# The sentence is : Bailey Thomas May Bailey Thomas May Bailey Thomas May Bailey Thomas May Bailey Thomas May Bailey Thomas May <USR> eighty four
# ***************
# The tags are B-musicartist I-musicartist I-musicartist B-musicartist I-musicartist I-musicartist B-musicartist I-musicartist I-musicartist B-musicartist I-musicartist I-musicartist B-musicartist I-musicartist I-musicartist B-musicartist I-musicartist I-musicartist O O O
# ============
# The sentence is : Photo : Chillo ?? Trying out for the 1st time this shit !! <URL>
# ***************
# The tags are O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Happy holidays , from our family to yours . May they be full of warmth , laughter , and those you love -- no matter how near or far .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Time to build dat hype for Tuesday ! Metal Gear Rising !: <URL>
# ***************
# The tags are O O O O O O O O O O O B-product I-product I-product O O
# ============
# The sentence is : 'RT <USR> Sprezzatura Time ( " But , I could play it in practice " ) #music #musicians <URL>'
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : I need to rest up tomorrow , only gonna leave the house if it 's absolutely necessary besides going to the mall in the evening that 's a must
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : me : i'm just going to rest my eyes for 4 minutes . me : *wakes up on September 5th , 2070 .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : mucho night zzz I DONT WANT TO WORK TOMORROW AND WEDNESDAY
# ***************
# The tags are O O O O O O O O O O O
# ============
# The sentence is : Preventing Public Health Disasters [ The Pump Handle] : Earlier this week , FDA Commissioner Margaret Hamburg present ... <URL>
# ***************
# The tags are O O O O O O O O O O O O O B-other O B-person I-person O O O
# ============
# The sentence is : Football game tonight with mariaelena , sarah , and brittany ! Mood : excited !! GOO WB WILDCATS !
# ***************
# The tags are O O O O B-person O B-person O O B-person O O O O O O B-sportsteam I-sportsteam O
# ============
# The sentence is : <USR> well I'm cleaning the house and thinking about next semester in Uni . Classes start in january .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Britain may be forced to ration the internet as power consumption soars <URL> <URL>
# ***************
# The tags are O O O B-geo-loc O O O O O O O O O O O O O
# ============
# The sentence is : TPCS Stingers dressing loud on May 13th to support Hearing Awareness Month .
# ***************
# The tags are B-sportsteam I-sportsteam O O O O O O O B-other I-other I-other O
# ============
# The sentence is : I swear that i`ll hold on to that promise i made on the 17 of March 2010 .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> No ... I'll try not too . I've missed too many days already ...
# ***************
# The tags are O O O O O O O O O O O O O O O
# ============
# The sentence is : Soccer #Livescore : ( ROU-2S2 ) #OlimpiaSatuMare vs #FCBihor : 0-1 . 2nd Half Started ...
# ***************
# The tags are O O O O B-sportsteam O B-sportsteam O B-sportsteam O O O O O O O
# ============
# The sentence is : 3 killed , 2 wounded in Atlanta shooting - San Francisco Chronicle - <URL> …
# ***************
# The tags are O O O O O O B-geo-loc O O B-company I-company I-company O O O
# ============
# The sentence is : RT <USR> : What is a watershed ? Virtual Field Trip LIVE <USR> April 8 ( gr . 3-8 ) #edchat #edtech #mschat <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : I 've just watched first four episodes of K-On for the first time ! : 3
# ***************
# The tags are O O O O O O O O B-tvshow O O O O O O O
# ============
# The sentence is : RT <USR> : Wonder Girls the 3rd album &lt; REBOOT &gt; Teaser Image #WonderGirls #REBOOT <URL>
# ***************
# The tags are O O O B-product I-product I-product I-product I-product O O O O O O O O
# ============
# The sentence is : Must say iPhone is more accurate . Wasnt brought up here though , Wrawby is where I spent 18 years of my life .
# ***************
# The tags are O O B-product O O O O O O O O O O B-geo-loc O O O O O O O O O O
# ============
# The sentence is : n dude .... one of the new choir teacher that they interviewed ( we had him all week ) gave us DONUTS !!!! haha hes nice
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Astaghfirullah for everything . May Allah forgive our sins . Lailahaillallah .
# ***************
# The tags are O O O O O O O O B-person O O O O O O
# ============
# The sentence is : " the moon is out and it 's huge...that 's the sun ."
# ***************
# The tags are O O O O O O O O O O O O O
# ============
# The sentence is : #Databreach at Middlesex Hospital may effect more than 900 patients , <USR> reports <URL> #security #healthIT
# ***************
# The tags are O O B-other I-other O O O O O O O O O O O O
# ============
# The sentence is : <USR> <USR> If I never flew with FlyDoha , I flew with Qatar last time on December then how could I copy your IFE ?
# ***************
# The tags are O O O O O O O B-company O O O O B-company O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Today , I saw a guy driving a Pepsi truck , drinking a Coke . MLIA #Quotealicious
# ***************
# The tags are O O O O O O O O O O O B-company O O O O B-product O O O
# ============
# The sentence is : I hate when someone ask you &quot; what 's wrong &quot; &amp; u say &quot; long story &quot; then they say &quot; I've got time &quot; okay I obviously don't want to tell you !
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : This September #AribyArianaGrande <URL>
# ***************
# The tags are O O O O O O O
# ============
# The sentence is : Sony hack is a serious breach of national security , US says <URL> #microsoft pic.twitter.com/NU2VO5Al8W "
# ***************
# The tags are B-company O O O O O O O O O B-geo-loc O O O O O
# ============
# The sentence is : RT <USR> : #nowplaying- This Is Our Someday - Big Time Rush &lt; 3 :)
# ***************
# The tags are O O O O B-other I-other I-other I-other O B-musicartist I-musicartist I-musicartist O O O
# ============
# The sentence is : RT <USR> : Somerset is 7-1 on games played on a Friday #GetPatriotic <URL>
# ***************
# The tags are O O O B-sportsteam O O O O O O O O O O
# ============
# The sentence is : this is what we do when we have no picture ideas . <URL>
# ***************
# The tags are O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Monday morning mood <URL>
# ***************
# The tags are O O O O O O O
# ============
# The sentence is : <USR> 10th november
# ***************
# The tags are O O O
# ============
# The sentence is : BORDER LINEA IS TONIGHT ! 9 p.m. to 2 a.m. NO COVER . Come by and see local musicians and artists showcased at Limelight on St . Mary's.
# ***************
# The tags are B-musicartist I-musicartist O O O O O O O O O O O O O O O O O O O O O B-facility O B-geo-loc I-geo-loc I-geo-loc
# ============
# The sentence is : sabar sat .. sakit sat jaa ..
# ***************
# The tags are O O O O O O O
# ============
# The sentence is : Colorado Springs shooting occurred at Chase Bank <URL> … via <USR>
# ***************
# The tags are B-geo-loc I-geo-loc O O O B-facility I-facility O O O O
# ============
# The sentence is : Is Joaquin Phoenix Our Modern Day Andy Kaufman ?: ... the bizarre events leading up to this moment , the movie could ... <URL>
# ***************
# The tags are O B-person I-person O O O B-person I-person O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> Nope . I think you believe she 's a time bomb and should be sacrificed if necessary .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : I can't wait till Friday tho
# ***************
# The tags are O O O O O O O O O
# ============
# The sentence is : can someone please rt my spam my birthday is on monday and i really want him to follow me :(
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : #AskEv your big questions about the new Twitter . com today at 1pm PST . 'll be responding from his own account (<USR>) . Make ...
# ***************
# The tags are O O O O O O O O O O B-company O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : 14 dead in San Bernardino shooting ; police have shot suspect connected to chase of black SUV <URL> Devastating .
# ***************
# The tags are O O O B-geo-loc I-geo-loc O O O O O O O O O O O O O O O
# ============
# The sentence is : Hackers nab 1.2 B passwords in colossal breach , says security firm - CNET <URL>
# ***************
# The tags are O O O O O O O O O O O O O B-company O
# ============
# The sentence is : Well-funded <URL> may be ecommerce game-changer - Yahoo News UK <URL> #martesTIC91
# ***************
# The tags are O O O O O O O B-company I-company I-company O O
# ============
# The sentence is : Relieved that the first full week of school is over ! So happy I can sleep in tomorrow !
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Dude look just like August . <URL>
# ***************
# The tags are O O O O O O O
# ============
# The sentence is : MITE SLEEP IN MY LIVINGROOM AINT DONE THAT FOR TIME ! #TRANSPORTER #E4
# ***************
# The tags are O O O O O O O O O O O O O
# ============
# The sentence is : Well , after a fast-paced week full of prayer from family and friends , I now have a full time job and I pretty much start Monday :-)
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> Sick fight ! I'll take my boy #aldo all day !
# ***************
# The tags are O O O O O O O O O O O O
# ============
# The sentence is : I'm gonna see Kendrick Lamar on Saturday &amp; it 's barely Monday , motherfuck make this week go faster :(
# ***************
# The tags are O O O B-musicartist I-musicartist O O O O O O O O O O O O O O O
# ============
# The sentence is : Michael__Myerz : |LIVE NOW| Yes #meerkat <URL> January 03 , 2016 at 06:54 AM
# ***************
# The tags are O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> haha maybe we'll dance off in the online stream tomorrow ! lol
# ***************
# The tags are O O O O O O O O O O O O O
# ============
# The sentence is : Come out to <USR> on Nov . 4th for the <USR> Pep Rally ! <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O
# ============
# The sentence is : I'm walking &amp; talking like money . Probably somewhere on the beach where the sun at
# ***************
# The tags are O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> haha I need to update my tan I feel so white . My face ! I have been tanning myself this month , hurry up summer !
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : It 's scary going to a religious college knowing that the shooting in roseburg was solely based on religion ...
# ***************
# The tags are O O O O O O O O O O O O O B-geo-loc O O O O O O
# ============
# The sentence is : Shame on SnapChat , Skype for breach <URL>
# ***************
# The tags are O O B-company O B-company O O O
# ============
# The sentence is : Puis je me coifferais avant mon anniv
# ***************
# The tags are O O O O O O O
# ============
# The sentence is : IM IRRIRATED AND ITS A FRIDAY
# ***************
# The tags are O O O O O O
# ============
# The sentence is : RT <USR> : #ZodiacFacts As a #Cancer you may find that your energy is just right for something really big .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Have yourselves freaky , funky holidays when Franny Stein hits the GLITTER game this February <URL> <URL>
# ***************
# The tags are O O O O O O O B-product I-product O O O O O O O O
# ============
# The sentence is : RT <USR> : my birthday is gonna be in 4 months y'all I'm gonna be 18 . eight ducking teen ( dec 30th mark y'all 's calendars )
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : #ZodiacFacts As a #Pisces you may find your thoughts racing so fast you can't keep up with them .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> The 9th'is going to be the bday of Lina : <USR> Please help me to make her the happiest girl in the world . -123
# ***************
# The tags are O O O O O O O O O B-person O O O O O O O O O O O O O O O O
# ============
# The sentence is : Snapchat 's Security Breach Exposes Broader Mobile Vulnerabilities <URL> <URL>
# ***************
# The tags are B-company O O O O O O O O O
# ============
# The sentence is : MGBSFL top-scorers : March 29 : Shacharit Donetsk hotshot Adam Ellis put daylight between himself a ... <URL> JewChronicle
# ***************
# The tags are B-other O O O O O B-sportsteam I-sportsteam O B-person I-person O O O O O O O O
# ============
# The sentence is : Fellas Don't just lick the PussyY , LOVE IT ! enjoy it . like u just got married &amp; the preacher said u may kiss the bride
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Coming to Costa Mesa January 30th , the <USR> : a fresh look at life , death , sex &amp; romance w/ <USR> ! <URL>
# ***************
# The tags are O O B-geo-loc I-geo-loc O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : MOTOGP : Round 13 , Motoland of Aragon , Spain , day one . Marlboro Ducati 's Casey Stoner wasted no time in taking ... <URL>
# ***************
# The tags are B-other O O O O O O B-geo-loc O B-geo-loc O O O O B-company I-company O B-person I-person O O O O O O O
# ============
# The sentence is : Of course , I was stunned . This , after all , was an inanimate object .
# ***************
# The tags are O O O O O O O O O O O O O O O O O
# ============
# The sentence is : My thoughts and prayers go out to the families involved in the Chattanooga shooting today .
# ***************
# The tags are O O O O O O O O O O O O B-geo-loc O O O
# ============
# The sentence is : RT <USR> : Queen of Peace . Tomorrow ... <URL>
# ***************
# The tags are O O O B-musicartist I-musicartist I-musicartist O O O O
# ============
# The sentence is : RT <USR> : Fuck yeah its FRIDAY !!
# ***************
# The tags are O O O O O O O O
# ============
# The sentence is : <USR> wth that 's such bullshit amboushy !!! Hahaha I'm just kidding ily I might come down tomorrow after work I just need a car wash
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : We are tied as the 5th band to compete in South 107 's Battle of the Bands next Friday for the spot to open for ... <URL>
# ***************
# The tags are O O O O O O O O O O B-company I-company O O O O O O O O O O O O O O O
# ============
# The sentence is : Your fiscal condition may be on the upswing , but don't let thi ... More for Scorpio <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O O B-other O
# ============
# The sentence is : <USR> <USR> <USR> alejo vive en mar del plata . Que puede saber de cosas del campo ?
# ***************
# The tags are O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : This is like the 1st time Directioners aren't in the drama .... Is this ... is this what .... freedom feels like ?
# ***************
# The tags are O O O O O O O O O B-other O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> Hari ini hari Rabu , Tanggal 01 Bulan April Tahun 2015 Jam 03:39 : 19
# ***************
# The tags are O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> <USR> <USR> <USR> atm digosok pake gosokan ? jan dong duitnya bisa buat beli jajan banyak itu
# ***************
# The tags are O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Conversations at work may not go as expected today , but they e ... More for Cancer <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O O B-other O
# ============
# The sentence is : Collins Cuthrell with a RBI single and we are tied at two in the 9th ! <URL>
# ***************
# The tags are B-person I-person O O O O O O O O O O O O O O O
# ============
# The sentence is : Sat , 27 Jun 2015 08:53 : 10 A1 AMBU LFL02 Zuidzijde 2977AM Goudriaan gou bon 57105 #p2000 #Rijnmond
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : VTech Hack Gets Worse : Chat Logs , Kids ' Photos Taken In Breach : An anonymous reader writes… <URL>
# ***************
# The tags are B-company O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : We present to you : TRUE ( and modern ) ISLAM , CHRISTIANITY , &amp; JUDAISM , ( all three , together ) in line WITH THE 21ST ... <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Ahaha , the look on <USR> ' s face when someone asks ' What part of the States are you from ?' is PRICELESS .
# ***************
# The tags are O O O O O O O O O O O O O O O O B-geo-loc I-geo-loc O O O O O O O
# ============
# The sentence is : in december 2005 dell recalled approximately 22,000 laptop computer batteries , and 4 .
# ***************
# The tags are O O O B-company O O O O O O O O O O
# ============
# The sentence is : I hate it when my [ HONK ! ] gets stuck in my [ WHOOPWHOOP] .
# ***************
# The tags are O O O O O O O O O O O O O O O O
# ============
# The sentence is : November is the best month ! - 6th Nov = Black Ops 3 - 8th Nov = My birthday - 13th Nov = <USR> 's album is released RT if you agree !
# ***************
# The tags are O O O O O O O O O O B-product I-product I-product O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : 9 days till <USR> 's 23rd birthday
# ***************
# The tags are O O O O O O O
# ============
# The sentence is : ANW : Update : TMZ Reporting Lindsay Lohan Just Failed Her Drug Test : We just congratulated Lindsay an hour ago on h ... <URL>
# ***************
# The tags are O O O O B-company O B-person I-person O O O O O O O O O B-person O O O O O O O
# ============
# The sentence is : Road snow is expected today on Milford Rd , Lindis Pass and Arthurs Pass today <URL> No warnings for Desert Rd , Lewis , Rimutakas
# ***************
# The tags are O O O O O O B-other I-other O B-geo-loc I-geo-loc O B-geo-loc I-geo-loc O O O O O B-other I-other O B-geo-loc O B-geo-loc
# ============
# The sentence is : <USR> I think i'm going to start buying chipotle for ONE lucky girl every week lol
# ***************
# The tags are O O O O O O O O B-product O O O O O O O
# ============
# The sentence is : <USR> thank you dear . But it 's not until the 13th . Your sentiments are much appreciated though . I hope that you are well .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : PRE ORDER WATERPROOF <URL> SAMPAI TGL 30 APRIL <USR> PIN BB 52AC28C6 SMS 089689681882
# ***************
# The tags are O O O O O O O O O O O O O O
# ============
# The sentence is : Let 's Vote ! #KCA #VoteJKT48ID April 10 , 2015 at 02:47 PM
# ***************
# The tags are O O O O O O O O O O O O O
# ============
# The sentence is : “<USR> : MORE : One 19 year old woman was shot 7 times at the shooting in Chicago this morning . She is expected to live . #Prayers”
# ***************
# The tags are O O O O O O O O O O O O O O O O O B-geo-loc O O O O O O O O O O
# ============
# The sentence is : <USR> aaahh sorry i posted the link wrong :( basically their record company confirmed the title &amp; it comes out nov 23 XD
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : struggled in locating parent room there and found out it was closed when we were there finally .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Haha I seen a ped egg called a foot cheese grater today . I found it proper hilarious xD
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> i know .. i need to stop before my room is gonna get filled with water .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : *VAROUFAKIS SAYS BANKS WILL OPEN TUESDAY AS NORMAL #Greece #Greferendum
# ***************
# The tags are B-person O O O O O O O O O
# ============
# The sentence is : Muhammad Youssef Abdulazeez : 5 Fast Facts You Need to Know <URL> …
# ***************
# The tags are B-person I-person I-person O O O O O O O O O O
# ============
# The sentence is : Have a practice session <USR> Field today at 6pm . Hope i shine well and start the next game . :)
# ***************
# The tags are O O O O B-facility I-facility O O O O O O O O O O O O O O O
# ============
# The sentence is : LAX shooting : A true explanation on why a gunman unleashed terror at Los Angeles International Air ... <URL> champagneAK
# ***************
# The tags are B-facility O O O O O O O O O O O O B-facility I-facility I-facility I-facility O O O
# ============
# The sentence is : RT <USR> : " You may say I'm a dreamer/but I'm not the only one " #ObamaRepealTheExecutiveOrder #venezuelaishope <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : If I choose to not attend school tomorrow,I'd be able to make pancakes and mashed potatoes in the morning !
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Happy Birthday <USR> ! May Allah s.w.t bless you with goodness and happiness .
# ***************
# The tags are O O O O O B-person O O O O O O O O
# ============
# The sentence is : 1st place baby #LGM
# ***************
# The tags are O O O O
# ============
# The sentence is : workin at the ol Sunset Bistro tonight ... come get some grub
# ***************
# The tags are O O O O B-facility I-facility O O O O O O
# ============
# The sentence is : Rab ne banaya sabko Par kaun bataey rab ko Mar ke tumpe Hum saans lete hai rab se karu jo duayein #PRDPWithFamily forty six
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> astonishing that game 5-6 is played in June 2016 , so clashes with Copa Centenario . Seems certain way to have B teams in Copa ?
# ***************
# The tags are O O O O O O O O O O O O O O B-other I-other O O O O O O O O O B-other O
# ============
# The sentence is : <USR> ... ive been to 13 30stm concerts now and you never got me on stage during/before kings and queens :( ((
# ***************
# The tags are O O O O O O B-musicartist O O O O O O O O O O B-musicartist I-musicartist I-musicartist O O
# ============
# The sentence is : <USR> May 's costume is the giant spider on her upper body . I 'm confused .
# ***************
# The tags are O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Praying for families/students in Marysville School shooting
# ***************
# The tags are O O O O B-facility I-facility O
# ============
# The sentence is : Pre Order jaket Korea CHELSEA " RIDE " sd 7 Jan , 185K belum ongkir <USR> SMS/WA 081235994171 pin 512A3491 <URL>
# ***************
# The tags are O O B-product I-product I-product I-product I-product I-product I-product O O O O O O O O O O O O
# ============
# The sentence is : dear youtube why does it take so long to upload a video gggrrrrr
# ***************
# The tags are O B-company O O O O O O O O O O O
# ============
# The sentence is : Interesting 1st week of work ( during training ) 1 of the 6 ppl decided the job wasnt for her , and the firm decided to let go another guy .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> nothing man . Tryna see was good for today . Was good with you ?
# ***************
# The tags are O O O O O O O O O O O O O O O O
# ============
# The sentence is : Good Tuesday Top discussions , Hash tags and more . Visit <URL> <URL>
# ***************
# The tags are O O O O O O O O O O O O O
# ============
# The sentence is : May is National Military Appreciation Month . Take a moment out during May to thank our service men and women for their sacrifices .
# ***************
# ...
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : <USR> titty Tuesday <URL>
# ***************
# The tags are O O O O O O O
# ============
# The sentence is : Soulja Boy | TheDeAndreWay . com - The DeAndre Way in stores Nov 2 , 2010 <URL> via <USR>
# ***************
# The tags are B-person I-person O O O O O B-other I-other I-other O O O O O O O O O
# ============
# The sentence is : <USR> <USR> <USR> not so accurate for here :) we have weekend on friday &amp; sat
# ***************
# The tags are O O O O O O O O O O O O O O O O
# ============
# The sentence is : Jueves 16 Jul : Parcialmente nuboso con lluvias . Temperaturas entre 17 C y 28 C . Viento 10 km/h dir . Sureste . #Maracay
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : oh NO . a golden vapor of the sun made human <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O
# ============
# The sentence is : Band hall . Game time . Lets get it .
# ***************
# The tags are B-facility I-facility O O O O O O O O
# ============
# The sentence is : Help Ricky and Co . pitch to <USR> on June 26th . <URL> #Voom <URL>
# ***************
# The tags are O B-person O O O O O O O O O O O O O
# ============
# The sentence is : Imma get your heart racing in my skin-tight jeans be your teenage dream tonight ....
# ***************
# The tags are O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : <USR> ' Honeymooners ' to Come to Charlestown on March 6 and 7 | Catonsville , MD Patch <URL>
# ***************
# The tags are O O O O O B-movie O O O O B-geo-loc O O O O O O B-geo-loc O B-geo-loc O O
# ============
# The sentence is : Federal lawsuit filed over police shooting <URL> #chicago
# ***************
# The tags are O O O O O O O O
# ============
# The sentence is : Another good turn out at our juniors #getintogolf session at 11.00 - 12.00 on a Saturday morning <USR> <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : I want it NOW ! ;) RT : <USR> Pumpkin Moonshine has arrived in Nashville -- Give it a week to get it in stores . KY ships next week !
# ***************
# The tags are O O O O O O O O O B-product I-product O O O B-geo-loc O O O O O O O O O O O B-geo-loc O O O O
# ============
# The sentence is : Dah september 2015 , Ada lagi manusia yang berebut ikan keli . Aih , Manusia .
# ***************
# The tags are O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : New from JS : Frustration ' extremely high ' for Slocum after 7th blocked kick <URL> #packers
# ***************
# The tags are O O O O O O O O O O O O O B-person O O O O O O
# ============
# The sentence is : ITIM YUNG TUBIG , GUYS . ITIM . TAPOS KANINANG UMAGA MAY MGA TAE PA SA KALSADA .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Ima be up there tomorrow dawg <URL>
# ***************
# The tags are O O O O O O O
# ============
# The sentence is : <USR> It 's the view from where I 'm living for two weeks . Empire State Building = ESB . Pretty bad storm here last evening .
# ***************
# The tags are O O O O O O O O O O O O O O B-facility I-facility I-facility O B-facility O O O O O O O O
# ============
# The sentence is : Nuevas experiencias culinarias , rana a la plancha ! @ Roquetas de Mar , Spain <URL>
# ***************
# The tags are O O O O O O O O O O B-geo-loc I-geo-loc I-geo-loc O B-geo-loc O
# ============
# The sentence is : RT <USR> : Salute ! <URL>
# ***************
# The tags are O O O O O O
# ============
# The sentence is : <USR> let me know if or when you are coming . #FullHouse
# ***************
# The tags are O O O O O O O O O O O O
# ============
# The sentence is : #Cartier - Cartier Must 21 2 TONE MENS Watch + CARTIER BOX MId Size : $ 800.00 ( 0 Bids)End Date : Sat ... <URL> #Deals_US
# ***************
# The tags are O O B-product I-product I-product I-product I-product I-product I-product I-product I-product I-product I-product I-product O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : november be like <URL>
# ***************
# The tags are O O O O O O O
# ============
# The sentence is : WFUNA Secretary-Generals Trip to Korea : September 2014 #HumanRights <URL> <URL>
# ***************
# The tags are B-other O O O B-geo-loc O O O O O O
# ============
# The sentence is : RT <USR> : Good evening friends . Welcome to our 5th episode of #MCEOTalk ! :) #MCEOtalk
# ***************
# The tags are O O O O O O O O O O O O O B-product O O O
# ============
# The sentence is : Get down to Cochrane an support the 1st XV , aiming to finish October undefeated . Huge game against Nottingham Uni #blueandwhitedynamite
# ***************
# The tags are O O O B-geo-loc O O O B-sportsteam I-sportsteam O O O O O O O O O O B-sportsteam I-sportsteam O
# ============
# The sentence is : i have pride in myself that one day i will be #1 girl of the week and u have pride in your self that your dream will come true ok love u !
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Interxion suffers security breach , customer contact details exposed <URL>
# ***************
# The tags are B-company O O O O O O O O O
# ============
# The sentence is : <USR> jan lupa makan nde
# ***************
# The tags are O O O O O
# ============
# The sentence is : Fuckin FRIDAY NIGHT , Tweople ( RIDE IT) ! <URL>
# ***************
# The tags are O O O O O O O O O O
# ============
# The sentence is : It is now 03:40 AM on Sunday , December 27 , 2015 ( US/Eastern) .
# ***************
# The tags are O O O O O O O O O O O O O O O
# ============
# The sentence is : When glass breaks , the cracks move faster than 3,000 miles per hour . To photograph it , a camera must shoot at a millionth of a second !
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Wtf ? The library closes on Friday ?
# ***************
# The tags are O O O O O O O O
# ============
# The sentence is : Okay , I'm kinda proud . I finished the first 8 books of the True Blood novels in 8 days .
# ***************
# The tags are O O O O O O O O O O O O O O B-tvshow I-tvshow O O O O O
# ============
# The sentence is : someone may need to take away my mind , to stop me constantly drowning in my thoughts .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Lamentable #ChattanoogaShooting en #usa y #elsalvador tienen q entender q los cobardes siempre atacan por la espaldapic.twitter.com/FwYsDhCacm
# ***************
# The tags are O O O B-geo-loc O B-geo-loc O O O O O O O O O O O
# ============
# The sentence is : It 's supposed to rain in The Bay on Sunday ... well , weather.com says &quot; showers &quot;. Whatever , same thing .
# ***************
# The tags are O O O O O O B-geo-loc I-geo-loc O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> hello hazza . Followback me please :" ( i from INDONESIA , hope you read this tweet , wait tomorrow u birthday^_^ #keeplonghair 264
# ***************
# The tags are O O O O O O O O O O O B-geo-loc O O O O O O O O O O O O O
# ============
# The sentence is : &quot; I gotta admit , Alex sounds hot when he talks in spanish during the ' Alejandro ' Cover &quot; -via someone 's tumblr
# ***************
# The tags are O O O O O B-person O O O O O O O O O O B-other O O O O O O B-company
# ============
# The sentence is : <USR> whispering cause I may have had 1 too many vodka 's last night and am a lil fragile , hold me ?
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : watching the VMAs Eminem is BeAsT and is smexy !!; )And Chelsea Handler is hilarious ! Finally got a boyfren he gave me the cutest thing today
# ***************
# The tags are O O B-other B-person O O O O O O O B-person I-person O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Dr . Dre 's new album featuring Kendrick , Eminem , Snoop Dogg &amp; more drops this Friday <URL>
# ***************
# The tags are O O O B-musicartist I-musicartist I-musicartist I-musicartist O O O B-musicartist O B-musicartist O B-musicartist I-musicartist O O O O O O
# ============
# The sentence is : You may need to stand up to a powerful person today , even if y ... More for Cancer <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O O O O B-other O
# ============
# The sentence is : H.E Museveni says we should not plan politics but continue doing our usual activities . He wants to adress issues of today not tomorrow's.
# ***************
# The tags are B-person I-person O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : U.S. Hotel Construction Pipeline for April 2015 Up 15.2 % over 2014 <URL> #HotelTrends #SmithTravelResearch
# ***************
# The tags are B-other I-other I-other I-other O O O O O O O O O O O
# ============
# The sentence is : Costa Rican group CocoFunka power this week 's Indiesent Exposure <URL> by <USR> on <USR>
# ***************
# The tags are O O O B-musicartist O O O O B-tvshow I-tvshow O O O O O
# ============
# The sentence is : RT <USR> : Me In the 6th grade <URL>
# ***************
# The tags are O O O O O O O O O
# ============
# The sentence is : <USR> making something to eat , aint ate all day
# ***************
# The tags are O O O O O O O O O O
# ============
# The sentence is : <USR> #Belgium #Shoppers #Survey EPC Familia - January sales erratic . <URL>
# ***************
# The tags are O B-geo-loc O O B-company I-company O O O O O O
# ============
# The sentence is : RT <USR> : <USR> AKO HAHAHA MAY EXAM PA NGA KAMI MAGKASUNOD NA SUBJECT ! HAHAHA FIRST AND SECOND PERIOD PA #ALDUBSaveMaine
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : #SIUC Whats the Plan For tonight ?? Whos Goin to the BLAST
# ***************
# The tags are O O O O O O O O O O B-facility I-facility
# ============
# The sentence is : taken a few minutes ago what do u think ??? :) <URL>
# ***************
# The tags are O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : when little mix releases their new single/3rd album <URL>
# ***************
# The tags are O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : remember that girl who ate her own tampon ? thats me because tomorrows monday
# ***************
# The tags are O O O O O O O O O O O O O O O O O
# ============
# The sentence is : 2 years and 9 months , but who 's counting . October 24th 2017 can't come soon enough .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Episodes 1-10 of Pretty Little Liars will air in the UK on October 18 !
# ***************
# The tags are O O O O O O B-tvshow I-tvshow I-tvshow O O O O B-geo-loc O O O O
# ============
# The sentence is : <USR> if recovery goes as planned for Wheeler and Flores is ok with playing 3rd full time .
# ***************
# The tags are O O O O O O O B-person O B-person O O O O O O O O
# ============
# The sentence is : [#NewarkWeather] , #Newark weather April 20 , 21 , 22 , 23 , 24 , 25 2015 <URL>
# ***************
# The tags are O O B-geo-loc O O O O O O O O O O O O O O O
# ============
# The sentence is : VW May Have To Sell Bentley , Lamborghini Or Ducati To Fund Dieselgate Loans <URL>
# ***************
# The tags are O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> i saw chelsea today u weren't there ? WTF
# ***************
# The tags are O O O B-person O O O O O O
# ============
# The sentence is : // Will start RPs tomorrow . Haven't RPed in a bit tbh .
# ***************
# The tags are O O O O O O O O O O O O O
# ============
# The sentence is : <URL> January 08 , 2015 at 12:14 AM
# ***************
# The tags are O O O O O O O O
# ============
# The sentence is : Who 's down to go hiking tomorrow
# ***************
# The tags are O O O O O O O
# ============
# The sentence is : RT <USR> : Niall leaving Nobu Restaurant in Malibu ( July 13th ) #13-16 <URL>
# ***************
# The tags are O O O B-musicartist O B-facility I-facility O B-geo-loc O O O O O O
# ============
# The sentence is : #sfgiants How many 1st pitches did Giants take for strikes , then go 0-2 on next pitch , anyone counting ? Teams know we don't swing at them
# ***************
# The tags are O O O O O O B-sportsteam O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Utilizing your creativity in the workplace may be necessary fo ... More for Pisces <URL>
# ***************
# The tags are O O O O O O O O O O O O O B-other O
# ============
# The sentence is : I couldn't even make it to Sunday <URL>
# ***************
# The tags are O O O O O O O O
# ============
# The sentence is : <USR> Ohhhh boozing on a Friday night !!! Try to behave Ma'am! Knickers on &amp; knees together please !!! Giggles Love Tanya xx
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> Mines the 9th
# ***************
# The tags are O O O O
# ============
# The sentence is : RT <USR> : MANA NIH PRILLVERS YANG BELOM BELI TIKET ANNIV KE 4TH ????
# ***************
# The tags are O O O O O O O O O O O O O O
# ============
# The sentence is : But actually how messed up are piercings , like who was the 1st person to say " hey stick this sharp thing through your head , it'll look hot "
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : May the Most High make us of those firm believers and may he guide those of us that are weak .
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Here 's an idea . Ernie Banks Day . Pick a Saturday every year and every team plays a scheduled double header that day .
# ***************
# The tags are O O O O O O O O B-person I-person O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Institutional buying lifts UFlex 30% in a month <URL>
# ***************
# The tags are O O O B-company O O O O O
# ============
# The sentence is : I just took " Justin Bieber takes 2 months off career to finish school , He is a huge ..." and got : Part 3 ! Try it : <URL>
# ***************
# The tags are O O O O B-person I-person O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : The last time I chatted with Kyle was June . The last time we emailed was August .
# ***************
# The tags are O O O O O O B-person O O O O O O O O O O O
# ============
# The sentence is : VIDEO : Showbiz Tonight - Is TV Too Gay ?: <URL>
# ***************
# The tags are O O B-tvshow I-tvshow O O O O O O O
# ============
# The sentence is : <USR> Wheeee !! Okay - we could get down there by like 9:30 if we want some shopping time and lunch before class . <USR>
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O
# ============
# The sentence is : Retailers face anonymous complaints if they breach grocery code of practice : <URL> …
# ***************
# The tags are O O O O O O O O O O O O O O
# ============
# The sentence is : Yay . <USR> is coming to see me next week ... plotting my cooking now !
# ***************
# The tags are O O O O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : MONSTER BOUNCE COMIN ON $VTCQ TOMORROW !!!!!!! IM LOADING THE BIDS AS I TWEET !!! #BMM <URL>
# ***************
# The tags are O O O B-sportsteam I-sportsteam O O O O O O O O O O O O O O O
# ============
# The sentence is : <USR> lets go on Saturday lol
# ***************
# The tags are O O O O O O
# ============
# The sentence is : time to get some sleep . been out from 4pm till now .
# ***************
# The tags are O O O O O O O O O O O O O
# ============
# The sentence is : RT <USR> : Man :" Is there any way for a long life ?" Doctor : " Get married ." Man :" Will it help ?" Doctor :" No , but the thought of long li ...
# ***************
# The tags are O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O
# ============

# %% [markdown]
# ## Build a recurrent neural network
#
# This is the most important part of the assignment. Here we will specify the network architecture based on TensorFlow building blocks. It's fun and easy as a lego constructor! We will create an LSTM network which will produce probability distribution over tags for each token in a sentence. To take into account both right and left contexts of the token, we will use Bi-Directional LSTM (Bi-LSTM). Dense layer will be used on top to perform tag classification.

# %%
import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# /Users/es.py/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# WARNING:tensorflow:From /Users/es.py/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks, Model
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional, Embedding

# %%
tf.random.set_random_seed(42)

# %%
n_words = len(token_to_index)

# %%
class BiLSTMModel():
    pass

# %% [markdown]
# First, we need to create [placeholders](https://www.tensorflow.org/api_docs/python/tf/compat/v1/placeholder) to specify what data we are going to feed into the network during the execution time.  For this task we will need the following placeholders:
#  - *input_batch* — sequences of words (the shape equals to [batch_size, sequence_len]);
#  - *ground_truth_tags* — sequences of tags (the shape equals to [batch_size, sequence_len]);
#  - *lengths* — lengths of not padded sequences (the shape equals to [batch_size]);
#  - *dropout_ph* — dropout keep probability; this placeholder has a predefined value 1;
#  - *learning_rate_ph* — learning rate; we need this placeholder because we want to change the value during training.
#
# It could be noticed that we use *None* in the shapes in the declaration, which means that data of any size can be feeded.
#
# You need to complete the function *declare_placeholders*.

# %%
BATCH_SIZE = 32
EPOCHS = 5
MAX_LEN = 75
EMBEDDING = 200
UNITS  = 200

# %%
def declare_placeholders(self):
    """Specifies placeholders for the model."""

    # Placeholders for input and ground truth output.
    self.input_batch = tf.placeholder(dtype=tf.int32, shape=[None, None], name='input_batch') 
    self.ground_truth_tags = tf.placeholder(dtype=tf.int32, shape=[None, None ], name='ground_truth_shape')
    # Placeholder for lengths of the sequences.
    self.lengths = tf.placeholder(dtype=tf.int32, shape=[None], name='lengths') 
    
    # Placeholder for a dropout keep probability. If we don't feed
    # a value for this placeholder, it will be equal to 1.0.
    self.dropout_ph = tf.placeholder_with_default(tf.cast(1.0, tf.float32), shape=[])
    
    # Placeholder for a learning rate (tf.float32).
    self.learning_rate_ph = tf.placeholder(dtype=tf.float32, shape=[], name='learning_rate')

# %%
BiLSTMModel.__declare_placeholders = classmethod(declare_placeholders)

# %% [markdown]
# Now, let us specify the layers of the neural network. First, we need to perform some preparatory steps:
#
# - Create embeddings matrix with [tf.Variable](https://www.tensorflow.org/api_docs/python/tf/Variable). Specify its name (*embeddings_matrix*), type  (*tf.float32*), and initialize with random values.
# - Create forward and backward LSTM cells. TensorFlow provides a number of RNN cells ready for you. We suggest that you use *LSTMCell*, but you can also experiment with other types, e.g. GRU cells. [This](http://colah.github.io/posts/2015-08-Understanding-LSTMs/) blogpost could be interesting if you want to learn more about the differences.
# - Wrap your cells with [DropoutWrapper](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper). Dropout is an important regularization technique for neural networks. Specify all keep probabilities using the dropout placeholder that we created before.
#
# After that, you can build the computation graph that transforms an input_batch:
#
# - [Look up](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) embeddings for an *input_batch* in the prepared *embedding_matrix*.
# - Pass the embeddings through [Bidirectional Dynamic RNN](https://www.tensorflow.org/api_docs/python/tf/nn/bidirectional_dynamic_rnn) with the specified forward and backward cells. Use the lengths placeholder here to avoid computations for padding tokens inside the RNN.
# - Create a dense layer on top. Its output will be used directly in loss function.
#
# Fill in the code below. In case you need to debug something, the easiest way is to check that tensor shapes of each step match the expected ones.

# %%
def build_layers(self, vocabulary_size, embedding_dim, n_hidden_rnn, n_tags):
    """Specifies bi-LSTM architecture and computes logits for inputs."""
    
    # Create embedding variable (tf.Variable) with dtype tf.float32
    initial_embedding_matrix = np.random.randn(vocabulary_size, embedding_dim) / np.sqrt(embedding_dim)
    embedding_matrix_variable = tf.Variable(initial_value = initial_embedding_matrix, dtype= tf.float32)
    
    # Create RNN cells (for example, tf.nn.rnn_cell.BasicLSTMCell) with n_hidden_rnn number of units 
    # and dropout (tf.nn.rnn_cell.DropoutWrapper), initializing all *_keep_prob with dropout placeholder.
    
    forward_cell = tf.nn.rnn_cell.LSTMCell(n_hidden_rnn)
    forward_cell = tf.nn.rnn_cell.DropoutWrapper(forward_cell, self.dropout_ph, self.dropout_ph)
    
    backward_cell = tf.nn.rnn_cell.LSTMCell(n_hidden_rnn)
    backward_cell = tf.nn.rnn_cell.DropoutWrapper(backward_cell, self.dropout_ph, self.dropout_ph)
    

    # Look up embeddings for self.input_batch (tf.nn.embedding_lookup).
    # Shape: [batch_size, sequence_len, embedding_dim].
    embedings = tf.nn.embedding_lookup(embedding_matrix_variable, self.input_batch)
    
    
    # Pass them through Bidirectional Dynamic RNN (tf.nn.bidirectional_dynamic_rnn).
    # Shape: [batch_size, sequence_len, 2 * n_hidden_rnn]. 
    # Also don't forget to initialize sequence_length as self.lengths and dtype as tf.float32.
    outputs, states = tf.nn.bidirectional_dynamic_rnn(cell_bw=backward_cell, 
                                                      cell_fw=forward_cell, 
                                                      dtype=tf.float32,
                                                      inputs=embedings,
                                                      sequence_length=self.lengths)
    
    output_fw, output_bw = outputs
    states_fw, states_bw = states
    rnn_output = tf.concat([output_fw, output_bw], axis=2)
    

    # Dense layer on top.
    # Shape: [batch_size, sequence_len, n_tags].   
    self.logits = tf.compat.v1.layers.dense(rnn_output, n_tags, activation=None)

# %%
BiLSTMModel.__build_layers = classmethod(build_layers)

# %% [markdown]
# To compute the actual predictions of the neural network, you need to apply [softmax](https://www.tensorflow.org/api_docs/python/tf/nn/softmax) to the last layer and find the most probable tags with [argmax](https://www.tensorflow.org/api_docs/python/tf/argmax).

# %%
def compute_predictions(self):
    """Transforms logits to probabilities and finds the most probable tags."""
    
    # Create softmax (tf.nn.softmax) function
    self. softmax_output = tf.nn.softmax(self.logits, name='softmax')
    
    # Use argmax (tf.argmax) to get the most probable tags
    # Don't forget to set axis=-1
    # otherwise argmax will be calculated in a wrong way
    predicitons = tf.math.argmax(self.softmax_output, axis=-1)
    self.predictions = predicitons

# %%
BiLSTMModel.__compute_predictions = classmethod(compute_predictions)

# %% [markdown]
# During training we do not need predictions of the network, but we need a loss function. We will use [cross-entropy loss](http://ml-cheatsheet.readthedocs.io/en/latest/loss_functions.html#cross-entropy), efficiently implemented in TF as
# [cross entropy with logits](https://www.tensorflow.org/api_docs/python/tf/nn/softmax_cross_entropy_with_logits_v2). Note that it should be applied to logits of the model (not to softmax probabilities!). Also note,  that we do not want to take into account loss terms coming from `<PAD>` tokens. So we need to mask them out, before computing [mean](https://www.tensorflow.org/api_docs/python/tf/reduce_mean).

# %%
def compute_loss(self, n_tags, PAD_index):
    """Computes masked cross-entopy loss with logits."""
    
    # Create cross entropy function function (tf.nn.softmax_cross_entropy_with_logits_v2)
    ground_truth_tags_one_hot = tf.one_hot(self.ground_truth_tags, n_tags)
    loss_tensor =  tf.nn.softmax_cross_entropy_with_logits(labels=ground_truth_tags_one_hot, logits=self.logits)
    
    mask = tf.cast(tf.not_equal(self.input_batch, PAD_index), tf.float32)
    # Create loss function which doesn't operate with <PAD> tokens (tf.reduce_mean)
    # Be careful that the argument of tf.reduce_mean should be
    # multiplication of mask and loss_tensor.
    self.loss = tf.reduce_mean(loss_tensor*mask)

# %%
BiLSTMModel.__compute_loss = classmethod(compute_loss)

# %% [markdown]
# The last thing to specify is how we want to optimize the loss.
# We suggest that you use [Adam](https://www.tensorflow.org/api_docs/python/tf/train/AdamOptimizer) optimizer with a learning rate from the corresponding placeholder.
# You will also need to apply clipping to eliminate exploding gradients. It can be easily done with [clip_by_norm](https://www.tensorflow.org/api_docs/python/tf/clip_by_norm) function.

# %%
def perform_optimization(self):
    """Specifies the optimizer and train_op for the model."""
    
    # Create an optimizer (tf.train.AdamOptimizer)
    self.optimizer =  tf.train.AdamOptimizer(learning_rate=self.learning_rate_ph)
    self.grads_and_vars = self.optimizer.compute_gradients(self.loss)
    
    # Gradient clipping (tf.clip_by_norm) for self.grads_and_vars
    # Pay attention that you need to apply this operation only for gradients 
    # because self.grads_and_vars also contains variables.
    # list comprehension might be useful in this case.
    clip_norm = tf.cast(1.0, tf.float32)
    self.grads_and_vars = [ (tf.clip_by_norm(gv[0], clip_norm),gv[1]) for gv in self.grads_and_vars]
    
    self.train_op = self.optimizer.apply_gradients(self.grads_and_vars)

# %%
BiLSTMModel.__perform_optimization = classmethod(perform_optimization)

# %% [markdown]
# Congratulations! You have specified all the parts of your network. You may have noticed, that we didn't deal with any real data yet, so what you have written is just recipes on how the network should function.
# Now we will put them to the constructor of our Bi-LSTM class to use it in the next section.

# %%
def init_model(self, vocabulary_size, n_tags, embedding_dim, n_hidden_rnn, PAD_index):
    self.__declare_placeholders()
    self.__build_layers(vocabulary_size, embedding_dim, n_hidden_rnn, n_tags)
    self.__compute_predictions()
    self.__compute_loss(n_tags, PAD_index)
    self.__perform_optimization()

# %%
BiLSTMModel.__init__ = classmethod(init_model)

# %% [markdown]
# ## Train the network and predict tags

# %% [markdown]
# [Session.run](https://www.tensorflow.org/api_docs/python/tf/Session#run) is a point which initiates computations in the graph that we have defined. To train the network, we need to compute *self.train_op*, which was declared in *perform_optimization*. To predict tags, we just need to compute *self.predictions*. Anyway, we need to feed actual data through the placeholders that we defined before.

# %%
def train_on_batch(self, session, x_batch, y_batch, lengths, learning_rate, dropout_keep_probability):
    #print("***"*4, y_batch.shape)
    feed_dict = {self.input_batch: x_batch,
                 self.ground_truth_tags: y_batch,
                 self.learning_rate_ph: learning_rate,
                 self.dropout_ph: dropout_keep_probability,
                 self.lengths: lengths}
    
    session.run(self.train_op, feed_dict=feed_dict)

# %%
BiLSTMModel.train_on_batch = classmethod(train_on_batch)

# %% [markdown]
# Implement the function *predict_for_batch* by initializing *feed_dict* with input *x_batch* and *lengths* and running the *session* for *self.predictions*.

# %%
def predict_for_batch(self, session, x_batch, lengths):
    feed_dict = {self.input_batch: x_batch,
                 self.lengths: lengths}
    predictions=session.run(self.predictions, feed_dict=feed_dict)
    softmax_output = session.run(self.softmax_output, feed_dict=feed_dict)
    return predictions, softmax_output

# %%
BiLSTMModel.predict_for_batch = classmethod(predict_for_batch)

# %% [markdown]
# We finished with necessary methods of our BiLSTMModel model and almost ready to start experimenting.
#
# ### Evaluation
# To simplify the evaluation process we provide two functions for you:
#  - *predict_tags*: uses a model to get predictions and transforms indices to tokens and tags;
#  - *eval_conll*: calculates precision, recall and F1 for the results.

# %%
from evaluation import precision_recall_f1

# %%
def predict_tags(model, session, token_idxs_batch, lengths):
    """Performs predictions and transforms indices to tokens and tags."""
    
    tag_indexes_batch, softmax_batch = model.predict_for_batch(session, token_idxs_batch, lengths)
    
    tags_batch, tokens_batch, probs_batch = [], [], []
    for tag_idxs, token_idxs, softmax_probs in zip(tag_indexes_batch, token_idxs_batch, softmax_batch):
        tags, tokens, probs = [], [], []
        for tag_idx, token_idx, softmax_prob in zip(tag_idxs, token_idxs, softmax_probs):
            if not index_to_tag[tag_idx]:
                print("following token index was not found.. *** " ,  token_idx)
            tags.append(index_to_tag[tag_idx])
            tokens.append(index_to_token[token_idx])
            probs.append(softmax_prob)
        tags_batch.append(tags)
        tokens_batch.append(tokens)
        probs_batch.append(probs)
    return tags_batch, tokens_batch, probs_batch
    
    
def eval_conll(model, session, tokens, tags, short_report=True):
    """Computes NER quality measures using CONLL shared task script."""
    
    y_true, y_pred = [], []
    for x_batch, y_batch, lengths in batches_generator(1, tokens, tags):
        tags_batch, tokens_batch, probs_batch = predict_tags(model, session, x_batch, lengths)
        if len(x_batch[0]) != len(tags_batch[0]):
            raise Exception("Incorrect length of prediction for the input, "
                            "expected length: %i, got: %i" % (len(x_batch[0]), len(tags_batch[0])))
        predicted_tags = []
        ground_truth_tags = []
        for gt_tag_idx, pred_tag, token in zip(y_batch[0], tags_batch[0], tokens_batch[0]): 
            if token != '&amp;amp;lt;PAD&amp;amp;gt;':
                ground_truth_tags.append(index_to_tag[gt_tag_idx])
                predicted_tags.append(pred_tag)

        # We extend every prediction and ground truth sequence with 'O' tag
        # to indicate a possible end of entity.
        y_true.extend(ground_truth_tags + ['O'])
        y_pred.extend(predicted_tags + ['O'])
    #print("do we have any empty tags? ", all(y_pred))
    results = precision_recall_f1(y_true=y_true, y_pred=y_pred, print_results=True, short_report=short_report)
    return results

# %% [markdown]
# ## Run your experiment

# %% [markdown]
# Create *BiLSTMModel* model with the following parameters:
#  - *vocabulary_size* — number of tokens;
#  - *n_tags* — number of tags;
#  - *embedding_dim* — dimension of embeddings, recommended value: 200;
#  - *n_hidden_rnn* — size of hidden layers for RNN, recommended value: 200;
#  - *PAD_index* — an index of the padding token (`<PAD>`).
#
# Set hyperparameters. You might want to start with the following recommended values:
# - *batch_size*: 32;
# - 4 epochs;
# - starting value of *learning_rate*: 0.005
# - *learning_rate_decay*: a square root of 2;
# - *dropout_keep_probability*: try several values: 0.1, 0.5, 0.9.
#
# However, feel free to conduct more experiments to tune hyperparameters and earn extra points for the assignment.

# %%
BATCH_SIZE = 32
EPOCHS = 5
MAX_LEN = 75
EMBEDDING = 200
UNITS  = 200

# %%
"""class BiLSTMModel(Model):
    def __init__(self, **kwargs):
        super(BiLSTMModel, self).__init__(**kwargs)
        self.embedding = Embedding(input_dim=n_words + 2 ,
                                   output_dim=EMBEDDING, 
                                   input_length=MAX_LEN,
                                   mask_zero=True)
        self.bidirectional = Bidirectional(LSTM(units=50, return_sequences=True, recurrent_dropout=.1))
        self.dense = Dense(1)
    def call(self, inputs):
        x = self.embedding(inputs)
        x = self.bidirectional(x)
        x = self.dense(x)
        return x"""
# Out:
# 'class BiLSTMModel(Model):\n    def __init__(self, **kwargs):\n        super(BiLSTMModel, self).__init__(**kwargs)\n        self.embedding = Embedding(input_dim=n_words + 2 ,\n                                   output_dim=EMBEDDING, \n                                   input_length=MAX_LEN,\n                                   mask_zero=True)\n        self.bidirectional = Bidirectional(LSTM(units=50, return_sequences=True, recurrent_dropout=.1))\n        self.dense = Dense(1)\n    def call(self, inputs):\n        x = self.embedding(inputs)\n        x = self.bidirectional(x)\n        x = self.dense(x)\n        return x'

# %%
"""bi_lstm_model = BiLSTMModel(name='ner_bi_directional_model')
bi_lstm_model.compile(optimizer='rmsprop',
                      loss='categorical_cross_entropy',
                      metrics=['accuracy'])
bi_lstm_model.summary()"""
# Out:
# "bi_lstm_model = BiLSTMModel(name='ner_bi_directional_model')\nbi_lstm_model.compile(optimizer='rmsprop',\n                      loss='categorical_cross_entropy',\n                      metrics=['accuracy'])\nbi_lstm_model.summary()"

# %%
len(index_to_token)
# Out:
# 20495

# %%
tf.compat.v1.reset_default_graph()
model = BiLSTMModel(vocabulary_size=len(token_to_index),
                    n_tags=len(tag_to_index),
                    embedding_dim=200
                    ,n_hidden_rnn=200,
                    PAD_index=token_to_index.get('<PAD>'))

batch_size = 32
n_epochs = 10
learning_rate = 0.005
learning_rate_decay = np.sqrt(2)
dropout_keep_probability = 0.75

# %% [markdown]
# If you got an error *"Tensor conversion requested dtype float64 for Tensor with dtype float32"* in this point, check if there are variables without dtype initialised. Set the value of dtype equals to *tf.float32* for such variables.

# %% [markdown]
# Finally, we are ready to run the training!

# %%
n_epochs
# Out:
# 10

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

print('Start training... \n')
for epoch in range(n_epochs):
    # For each epoch evaluate the model on train and validation data
    print('-' * 20 + ' Epoch {} '.format(epoch+1) + 'of {} '.format(n_epochs) + '-' * 20)
    print('Train data evaluation:')
    eval_conll(model, sess, train_tokens, train_tags, short_report=True)
    print('Validation data evaluation:')
    eval_conll(model, sess, validation_tokens, validation_tags, short_report=True)
    
    # Train the model
    for x_batch, y_batch, lengths in batches_generator(batch_size, train_tokens, train_tags):
        model.train_on_batch(sess, x_batch, y_batch, lengths, learning_rate, dropout_keep_probability)
        
    # Decaying the learning rate
    learning_rate = learning_rate / learning_rate_decay
    
print('...training finished.')
# Out:
# Start training...
#
# -------------------- Epoch 1 of 10 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 76253 phrases; correct: 213.
#
# precision:  0.28%; recall:  4.74%; F1:  0.53
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 9357 phrases; correct: 25.
#
# precision:  0.27%; recall:  4.66%; F1:  0.51
#
# -------------------- Epoch 2 of 10 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 3122 phrases; correct: 870.
#
# precision:  27.87%; recall:  19.38%; F1:  22.86
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 231 phrases; correct: 73.
#
# precision:  31.60%; recall:  13.59%; F1:  19.01
#
# -------------------- Epoch 3 of 10 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4922 phrases; correct: 2649.
#
# precision:  53.82%; recall:  59.01%; F1:  56.30
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 383 phrases; correct: 153.
#
# precision:  39.95%; recall:  28.49%; F1:  33.26
#
# -------------------- Epoch 4 of 10 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4790 phrases; correct: 3473.
#
# precision:  72.51%; recall:  77.37%; F1:  74.86
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 425 phrases; correct: 185.
#
# precision:  43.53%; recall:  34.45%; F1:  38.46
#
# -------------------- Epoch 5 of 10 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4799 phrases; correct: 4038.
#
# precision:  84.14%; recall:  89.95%; F1:  86.95
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 516 phrases; correct: 208.
#
# precision:  40.31%; recall:  38.73%; F1:  39.51
#
# -------------------- Epoch 6 of 10 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4544 phrases; correct: 4187.
#
# precision:  92.14%; recall:  93.27%; F1:  92.70
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 370 phrases; correct: 182.
#
# precision:  49.19%; recall:  33.89%; F1:  40.13
#
# -------------------- Epoch 7 of 10 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4579 phrases; correct: 4310.
#
# precision:  94.13%; recall:  96.01%; F1:  95.06
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 438 phrases; correct: 193.
#
# precision:  44.06%; recall:  35.94%; F1:  39.59
#
# -------------------- Epoch 8 of 10 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4520 phrases; correct: 4383.
#
# precision:  96.97%; recall:  97.64%; F1:  97.30
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 421 phrases; correct: 188.
#
# precision:  44.66%; recall:  35.01%; F1:  39.25
#
# -------------------- Epoch 9 of 10 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4527 phrases; correct: 4419.
#
# precision:  97.61%; recall:  98.44%; F1:  98.03
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 458 phrases; correct: 192.
#
# precision:  41.92%; recall:  35.75%; F1:  38.59
#
# -------------------- Epoch 10 of 10 --------------------
# Train data evaluation:
# processed 105778 tokens with 4489 phrases; found: 4534 phrases; correct: 4434.
#
# precision:  97.79%; recall:  98.77%; F1:  98.28
#
# Validation data evaluation:
# processed 12836 tokens with 537 phrases; found: 464 phrases; correct: 195.
#
# precision:  42.03%; recall:  36.31%; F1:  38.96
#
# ...training finished.

# %% [markdown]
# Now let us see full quality reports for the final model on train, validation, and test sets. To give you a hint whether you have implemented everything correctly, you might expect F-score about 40% on the validation set.
#
# **The output of the cell below (as well as the output of all the other cells) should be present in the notebook for peer2peer review!**

# %%
print('-' * 20 + ' Train set quality: ' + '-' * 20)
train_results = eval_conll(model, sess, train_tokens, train_tags, short_report=False)

print('-' * 20 + ' Validation set quality: ' + '-' * 20)
validation_results = eval_conll(model, sess, validation_tokens, validation_tags, short_report=False)

print('-' * 20 + ' Test set quality: ' + '-' * 20)
test_results = eval_conll(model, sess, test_tokens, test_tags, short_report=False)
# Out:
# -------------------- Train set quality: --------------------
# processed 105778 tokens with 4489 phrases; found: 4518 phrases; correct: 4447.
#
# precision:  98.43%; recall:  99.06%; F1:  98.75
#
# 	     company: precision:   98.46%; recall:   99.53%; F1:   98.99; predicted:   650
#
# 	    facility: precision:   96.26%; recall:   98.41%; F1:   97.32; predicted:   321
#
# 	     geo-loc: precision:   99.60%; recall:   99.80%; F1:   99.70; predicted:   998
#
# 	       movie: precision:   98.48%; recall:   95.59%; F1:   97.01; predicted:    66
#
# 	 musicartist: precision:   98.28%; recall:   98.28%; F1:   98.28; predicted:   232
#
# 	       other: precision:   96.49%; recall:   98.15%; F1:   97.31; predicted:   770
#
# 	      person: precision:   99.66%; recall:   99.77%; F1:   99.72; predicted:   887
#
# 	     product: precision:   98.75%; recall:   99.06%; F1:   98.90; predicted:   319
#
# 	  sportsteam: precision:   97.72%; recall:   98.62%; F1:   98.17; predicted:   219
#
# 	      tvshow: precision:   98.21%; recall:   94.83%; F1:   96.49; predicted:    56
#
# -------------------- Validation set quality: --------------------
# processed 12836 tokens with 537 phrases; found: 449 phrases; correct: 188.
#
# precision:  41.87%; recall:  35.01%; F1:  38.13
#
# 	     company: precision:   54.90%; recall:   53.85%; F1:   54.37; predicted:   102
#
# 	    facility: precision:   36.11%; recall:   38.24%; F1:   37.14; predicted:    36
#
# 	     geo-loc: precision:   76.71%; recall:   49.56%; F1:   60.22; predicted:    73
#
# 	       movie: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:    13
#
# 	 musicartist: precision:   17.65%; recall:   10.71%; F1:   13.33; predicted:    17
#
# 	       other: precision:   29.63%; recall:   29.63%; F1:   29.63; predicted:    81
#
# 	      person: precision:   46.67%; recall:   25.00%; F1:   32.56; predicted:    60
#
# 	     product: precision:   12.90%; recall:   11.76%; F1:   12.31; predicted:    31
#
# 	  sportsteam: precision:   15.38%; recall:   20.00%; F1:   17.39; predicted:    26
#
# 	      tvshow: precision:    0.00%; recall:    0.00%; F1:    0.00; predicted:    10
#
# -------------------- Test set quality: --------------------
# --------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-51-a0a9d4ae938c> in <module>
#       6
#       7 print('-' * 20 + ' Test set quality: ' + '-' * 20)
# ----> 8 test_results = eval_conll(model, sess, test_tokens, test_tags, short_report=False)
#
# <ipython-input-43-b10b043b9f20> in eval_conll(model, session, tokens, tags, short_report)
#      23
#      24     y_true, y_pred = [], []
# ---> 25     for x_batch, y_batch, lengths in batches_generator(1, tokens, tags):
#      26         tags_batch, tokens_batch, probs_batch = predict_tags(model, session, x_batch, lengths)
#      27         if len(x_batch[0]) != len(tags_batch[0]):
#
# <ipython-input-18-7ec6dfbdce60> in batches_generator(batch_size, tokens, tags, shuffle, allow_smaller_last_batch)
#      33         for n in range(current_batch_size):
#      34             utt_len = len(x_list[n])
# ---> 35             x[n, :utt_len] = x_list[n]
#      36             lengths[n] = utt_len
#      37             y[n, :utt_len] = y_list[n]
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %% [markdown]
# ### Conclusions
#
# Could we say that our model is state of the art and the results are acceptable for the task? Definately, we can say so. Nowadays, Bi-LSTM is one of the state of the art approaches for solving NER problem and it outperforms other classical methods. Despite the fact that we used small training corpora (in comparison with usual sizes of corpora in Deep Learning), our results are quite good. In addition, in this task there are many possible named entities and for some of them we have only several dozens of trainig examples, which is definately small. However, the implemented model outperforms classical CRFs for this task. Even better results could be obtained by some combinations of several types of methods, e.g. see [this](https://arxiv.org/abs/1603.01354) paper if you are interested.
